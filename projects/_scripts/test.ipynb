# %%
import os

# %% [markdown]
# # generate old project pages

# %%
projects = os.listdir("./")

# %%
for project in projects:
    if project=="test.ipynb": continue
    title = " ".join(project.split("-")).title()
    file_format = f"""---
layout: project
permalink: {project}
title: {title}
tag: {project}
enable_nav: false
---
    """
    with open(f'./{project}/{project}.md', 'w') as f:
        f.write(file_format)
    print(file_format)
# Out:
# ---
# layout: project
# permalink: aerial-lidar
# title: Aerial Lidar
# tag: aerial-lidar
# enable_nav: false
# ---
#
# ---
# layout: project
# permalink: angry-birds
# title: Angry Birds
# tag: angry-birds
# enable_nav: false
# ---
#
# ---
# layout: project
# permalink: auto-airplanes
# title: Auto Airplanes
# tag: auto-airplanes
# enable_nav: false
# ---
#
# ---
# layout: project
# permalink: auto-copters
# title: Auto Copters
# tag: auto-copters
# enable_nav: false
# ---
#
# ---
# layout: project
# permalink: aye-aye
# title: Aye Aye
# tag: aye-aye
# enable_nav: false
# ---
#
# ---
# layout: project
# permalink: bird-net-tracker
# title: Bird Net Tracker
# tag: bird-net-tracker
# enable_nav: false
# ---
#
# ---
# layout: project
# permalink: burrowing-owls
# title: Burrowing Owls
# tag: burrowing-owls
# enable_nav: false
# ---
#
# ---
# layout: project
# permalink: condor-cam
# title: Condor Cam
# tag: condor-cam
# enable_nav: false
# ---
#
# ---
# layout: project
# permalink: del-dios-monitoring
# title: Del Dios Monitoring
# tag: del-dios-monitoring
# enable_nav: false
# ---
#
# ---
# layout: project
# permalink: elephant-monitoring
# title: Elephant Monitoring
# tag: elephant-monitoring
# enable_nav: false
# ---
#
# ---
# layout: project
# permalink: Intelligent-camera-trap
# title: Intelligent Camera Trap
# tag: Intelligent-camera-trap
# enable_nav: false
# ---
#
# ---
# layout: project
# permalink: maya-achaeology
# title: Maya Achaeology
# tag: maya-achaeology
# enable_nav: false
# ---
#
# ---
# layout: project
# permalink: Nautical Archaeology
# title: Nautical Archaeology
# tag: Nautical Archaeology
# enable_nav: false
# ---
#
# ---
# layout: project
# permalink: openrov
# title: Openrov
# tag: openrov
# enable_nav: false
# ---
#
# ---
# layout: project
# permalink: searching-for-harpy-eagles
# title: Searching For Harpy Eagles
# tag: searching-for-harpy-eagles
# enable_nav: false
# ---
#
# ---
# layout: project
# permalink: stabilized-aerial-camera-platform
# title: Stabilized Aerial Camera Platform
# tag: stabilized-aerial-camera-platform
# enable_nav: false
# ---
#
# ---
# layout: project
# permalink: terrestrial-vechicle
# title: Terrestrial Vechicle
# tag: terrestrial-vechicle
# enable_nav: false
# ---
#
# ---
# layout: project
# permalink: tiger-tracking
# title: Tiger Tracking
# tag: tiger-tracking
# enable_nav: false
# ---
#
# ---
# layout: project
# permalink: tunnel-bot
# title: Tunnel Bot
# tag: tunnel-bot
# enable_nav: false
# ---
#
# ---
# layout: project
# permalink: underwater-cave-imaging
# title: Underwater Cave Imaging
# tag: underwater-cave-imaging
# enable_nav: false
# ---
#
# ---
# layout: project
# permalink: vaquita-monitoring
# title: Vaquita Monitoring
# tag: vaquita-monitoring
# enable_nav: false
# ---
#
# ---
# layout: project
# permalink: wolf-monitoring
# title: Wolf Monitoring
# tag: wolf-monitoring
# enable_nav: false
# ---

# %% [markdown]
# # auto formatter

# %%
import requests

# %%
request = requests.get("https://e4e.ucsd.edu/past-projects")

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(request.text)

# %%
images = soup.find(id="primary").find_all("img")

# %%
asset_folder = "../../assets/projects/_old_projects/"
asset_folder_md = "assets/projects/_old_projects/"
for image in images:
    
    src = image["src"]
    filename = src.split("/")[-1]
    print('![]({{' +asset_folder_md + filename+ ' | absolute_url}}') 

    data = requests.get(src).content 
    
    # Opening a new file named img with extension .jpg 
    # This file would store the data of the image file 
    f = open(asset_folder + filename,'wb') 
    
    # Storing the image data inside the data variable to the file 
    f.write(data) 
    f.close()
# Out:
# ![]({{assets/projects/_old_projects/lubrak-village-frontal-ps3_edited-e1654024061974.jpg | absolute_url}}
# ![]({{assets/projects/_old_projects/aye-aye-baby_250x250.jpg | absolute_url}}
# ![]({{assets/projects/_old_projects/burronw_owl_thumbnail.png | absolute_url}}
# ![]({{assets/projects/_old_projects/project_mayaarchaeology.jpg | absolute_url}}
# ![]({{assets/projects/_old_projects/tahoe_underwater.jpg | absolute_url}}
# ![]({{assets/projects/_old_projects/project_angrybirds4.jpg | absolute_url}}
# ![]({{assets/projects/_old_projects/elephant_monitoring_thumb.jpg | absolute_url}}
# ![]({{assets/projects/_old_projects/tiger_tracker_thumb.jpg | absolute_url}}
# ![]({{assets/projects/_old_projects/wolf_tracking_thumb.jpg | absolute_url}}
# ![]({{assets/projects/_old_projects/bird_nest_thumb.jpg | absolute_url}}
# ![]({{assets/projects/_old_projects/project_deldios.jpg | absolute_url}}
# ![]({{assets/projects/_old_projects/aerial_lidar_thumb.jpg | absolute_url}}
# ![]({{assets/projects/_old_projects/autonomous_plane_thumb.jpg | absolute_url}}
# ![]({{assets/projects/_old_projects/copter_thumb.jpg | absolute_url}}
# ![]({{assets/projects/_old_projects/project_condorcam.png | absolute_url}}
# ![]({{assets/projects/_old_projects/project_balloon.jpg | absolute_url}}
# ![]({{assets/projects/_old_projects/project_cameratrap.jpg | absolute_url}}
# ![]({{assets/projects/_old_projects/project_vehicle.jpg | absolute_url}}
# ![]({{assets/projects/_old_projects/project_tunnelbot.jpg | absolute_url}}
# ![]({{assets/projects/_old_projects/openrov.jpg | absolute_url}}
# ![]({{assets/projects/_old_projects/underwater_cave_mapping_thumb.jpg | absolute_url}}
# ![]({{assets/projects/_old_projects/vaquita_monitoring.jpg | absolute_url}}
# ![]({{assets/projects/_old_projects/harpy-eagle.jpg | absolute_url}}

# %%
request = requests.get("http://localhost:4000/stabilized-aerial-camera-platform/media")
soup = BeautifulSoup(request.text)
images = soup.find(id="primary").find_all("img")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 3
#       1 request = requests.get("http://localhost:4000/stabilized-aerial-camera-platform/media")
#       2 soup = BeautifulSoup(request.text)
# ----> 3 images = soup.find(id="primary").find_all("img")
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en"><head><script>
#   document.write(
#     '<script src="' + location.protocol + '//' +
#     (location.host || 'localhost').split(':')[0] +
#     ':35729/livereload.js?snipver=1&amp;port=35729"' +
#     '></' +
#     'script>');
# </script>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/><!-- Begin Jekyll SEO tag v2.8.0 -->
# <title>Stabilized Aerial Camera Platform | UCSD Engineers For Exploration</title>
# <meta content="Jekyll v4.3.3" name="generator">
# <meta content="Stabilized Aerial Camera Platform" property="og:title">
# <meta content="en_US" property="og:locale">
# <link href="http://localhost:4000/stabilized-aerial-camera-platform/media" rel="canonical"/>
# <meta content="http://localhost:4000/stabilized-aerial-camera-platform/media" property="og:url"/>
# <meta content="UCSD Engineers For Exploration" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="Stabilized Aerial Camera Platform" property="twitter:title"/>
# <script type="application/ld+json">
# {"@context":"https://schema.org","@type":"WebPage","headline":"Stabilized Aerial Camera Platform","url":"http://localhost:4000/stabilized-aerial-camera-platform/media"}</script>
# <!-- End Jekyll SEO tag -->
# <link href="http://localhost:4000/assets/main.css" rel="stylesheet"/>
# <link href="http://localhost:4000/e4esquarelogo-v2.png" rel="shortcut icon" type="image/png"/><link href="http://localhost:4000/feed.xml" rel="alternate" title="UCSD Engineers For Exploration" type="application/atom+xml"/></meta></meta></meta></head>
# <body><header class="site-header" role="banner">
# <div class="wrapper"><a class="site-title" href="/" rel="author"><img class="main_logo" src="http://localhost:4000/e4e_website-no-e4e.png" title="UCSD Engineers For Exploration"/></a><nav class="site-nav">
# <input class="nav-trigger" id="nav-trigger" type="checkbox"/>
# <label for="nav-trigger">
# <span class="menu-icon">
# <svg height="15px" viewbox="0 0 18 15" width="18px">
# <path d="M18,1.484c0,0.82-0.665,1.484-1.484,1.484H1.484C0.665,2.969,0,2.304,0,1.484l0,0C0,0.665,0.665,0,1.484,0 h15.032C17.335,0,18,0.665,18,1.484L18,1.484z M18,7.516C18,8.335,17.335,9,16.516,9H1.484C0.665,9,0,8.335,0,7.516l0,0 c0-0.82,0.665-1.484,1.484-1.484h15.032C17.335,6.031,18,6.696,18,7.516L18,7.516z M18,13.516C18,14.335,17.335,15,16.516,15H1.484 C0.665,15,0,14.335,0,13.516l0,0c0-0.82,0.665-1.483,1.484-1.483h15.032C17.335,12.031,18,12.695,18,13.516L18,13.516z"></path>
# </svg>
# </span>
# </label>
# <div class="menu-navigation-container">
# <ul class="menu">
# <li class="menu-item"><a href="http://localhost:4000/">Home</a>
# </li>
# <li class="menu-item"><a href="http://localhost:4000/about">About</a>
# <ul class="sub-menu">
# <li><a href="http://localhost:4000/open-opportunities">Open Opportunities - Academic Year</a></li>
# <li><a href="http://localhost:4000/contact">Contact</a></li>
# <li><a href="http://localhost:4000/people">Current Students</a></li>
# <li><a href="http://localhost:4000/alumni">Alumni</a></li>
# <li><a href="http://localhost:4000/publications">Publications</a></li>
# <li><a href="http://localhost:4000/expeditions">Expeditions</a></li>
# </ul>
# </li>
# <li class="menu-item"><a href="http://localhost:4000/projects">Projects</a>
# <ul class="sub-menu">
# <li><a href="http://localhost:4000/radio-collar-tracker">Radio Telemetry Tracker</a></li>
# <li><a href="http://localhost:4000/baboons-on-the-move">Baboons on the Move</a></li>
# <li><a href="http://localhost:4000/acoustic-species-identification">Acoustic Species Identification</a></li>
# <li><a href="http://localhost:4000/mangrove-monitoring">Mangrove Monitoring</a></li>
# <li><a href="http://localhost:4000/smartfin">Smartfin</a></li>
# <li><a href="http://localhost:4000/fishsense">FishSense</a></li>
# <li><a href="http://localhost:4000/floods-of-lubra">Floods of Lubra</a></li>
# <li><a href="http://localhost:4000/research-support-group">Research Support Group</a></li>
# <li><a href="http://localhost:4000/past-projects">Past Projects</a></li>
# </ul>
# </li>
# <li class="menu-item"><a href="http://localhost:4000/calendar">Calendar</a>
# </li>
# <li class="menu-item"><a href="http://localhost:4000/welcome">How to join</a>
# <ul class="sub-menu">
# <li><a href="http://localhost:4000/open-opportunities">Open Opportunities - Academic Year</a></li>
# <li><a href="http://localhost:4000/onboarding-papers">Onboarding Papers</a></li>
# <li><a href="http://localhost:4000/tips-for-effective-applications">Tips for Effective Applications</a></li>
# </ul>
# </li>
# </ul>
# </div>
# </nav></div>
# </header>
# <main aria-label="Content" class="page-content">
# <div class="wrapper">
# <div class="feed"><h1 class="page-heading">Stabilized Aerial Camera Platform Media</h1><nav id="project-navigation">
# <ul class="menu-project" id="menu-project-nav">
# <li class="menu-projects" id="">
# <a href="./">
#             Stabilized Aerial Camera Platform
#             </a>
# </li>
# <li class="menu-projects" id="">
# <a href="./project-updates">
#             Project Updates
#             </a>
# </li>
# <li class="menu-projects" id="">
# <a aria-current="page">
#             Media
#             </a>
# </li>
# </ul>
# </nav><div class="gallery"></div><!-- https://www.w3schools.com/css/css_grid.asp -->
# <style>
#             .gallery {
#                 display: flex;
#                 flex-direction: row;
#                 flex-wrap: wrap;
#                 justify-content: space-evenly;
#                 /* grid-template-columns: auto auto auto; */
#                 gap: 10px;
#             }
#
#             .image_container {
#                 height: 200px;
#                 width: 200px;
#             }
#
#             img {
#                 object-fit: cover;
#                 width: 100%;
#                 height: 100%;
#             }
#
#
#         </style>
# </div>
# </div>
#
# </main><footer class="site-footer h-card">
# <data class="u-url" href="/"></data>
# <div class="wrapper">
# <h2 class="footer-heading">UCSD Engineers For Exploration</h2>
# <div class="footer-col-wrapper">
# <div class="footer-col footer-col-1">
# <ul class="contact-list">
# <li class="p-name">UCSD Engineers For Exploration</li><li><a class="u-email" href="mailto:e4e@ucsd.edu">e4e@ucsd.edu</a></li></ul>
# </div>
# <div class="footer-col footer-col-2"><div id="social_icons"><a href="https://www.facebook.com/ucsde4e"><svg class="svg-icon"><use xlink:href="/assets/minima-social-icons.svg#facebook"></use></svg> <span class="username"></span></a><a href="https://www.flickr.com/photos/ucsd-e4e"><svg class="svg-icon"><use xlink:href="/assets/minima-social-icons.svg#flickr"></use></svg> <span class="username"></span></a><a href="https://github.com/UCSD-E4E"><svg class="svg-icon"><use xlink:href="/assets/minima-social-icons.svg#github"></use></svg> <span class="username"></span></a><a href="https://instagram.com/ucsde4e"><svg class="svg-icon"><use xlink:href="/assets/minima-social-icons.svg#instagram"></use></svg> <span class="username"></span></a><a href="https://www.linkedin.com/company/e4e-ucsd"><svg class="svg-icon"><use xlink:href="/assets/minima-social-icons.svg#linkedin"></use></svg> <span class="username"></span></a><a href="https://www.twitter.com/ucsde4e"><svg class="svg-icon"><use xlink:href="/assets/minima-social-icons.svg#twitter"></use></svg> <span class="username"></span></a><a href="https://youtube.com/%40ucsde4e"><svg class="svg-icon"><use xlink:href="/assets/minima-social-icons.svg#youtube"></use></svg> <span class="username"></span></a></div>
# </div>
# <div class="footer-col footer-col-3">
# <p></p>
# </div>
# </div>
# </div>
# </footer>
# </body>
# </html>

# %%
def download_images(asset_folder, og_webpage):
    request = requests.get(og_webpage)
    soup = BeautifulSoup(request.text)
    images = soup.find(id="primary").find_all("img")
    
    asset_folder_md = asset_folder.replace("../", "")
    for image in images:
        src = image["src"]
        filename = src.split("/")[-1]
        print('![]({{' +asset_folder_md + filename+ ' | absolute_url}}') 

        data = requests.get(src).content 
        
        # Opening a new file named img with extension .jpg 
        # This file would store the data of the image file 
        f = open(asset_folder + filename,'wb') 
        
        # Storing the image data inside the data variable to the file 
        f.write(data) 
        f.close()

# %%
download_images("../../assets/projects_old_projects_scap_", "https://e4e.ucsd.edu/stabilized-aerial-camera-platform/media")
# Out:
# ![]({{assets/projects_old_projects_scap_11376395096_e04cb8c75f.jpg | absolute_url}}
# ![]({{assets/projects_old_projects_scap_11376448196_01f4d3cfe7.jpg | absolute_url}}
# ![]({{assets/projects_old_projects_scap_11376761866_7120d1ac87.jpg | absolute_url}}
# ![]({{assets/projects_old_projects_scap_11376884923_de9ac42250.jpg | absolute_url}}
# ![]({{assets/projects_old_projects_scap_11376800854_4c873b40d0.jpg | absolute_url}}
# ![]({{assets/projects_old_projects_scap_11377365714_f8c537ae7d.jpg | absolute_url}}
# ![]({{assets/projects_old_projects_scap_11378246733_49cfcb045e.jpg | absolute_url}}
# ![]({{assets/projects_old_projects_scap_11378113635_e7da50bde1.jpg | absolute_url}}
# ![]({{assets/projects_old_projects_scap_11377732954_827c877193.jpg | absolute_url}}
# ![]({{assets/projects_old_projects_scap_11377732024_68f2a33cba.jpg | absolute_url}}
# ![]({{assets/projects_old_projects_scap_11377016596_25cdf0e65d.jpg | absolute_url}}
# ![]({{assets/projects_old_projects_scap_11376999105_496bcb55f7.jpg | absolute_url}}
# ![]({{assets/projects_old_projects_scap_11377595915_7ede5d97a4.jpg | absolute_url}}
# ![]({{assets/projects_old_projects_scap_13073934435_9e5bebe514.jpg | absolute_url}}
# ![]({{assets/projects_old_projects_scap_13074247494_fce8bce32c.jpg | absolute_url}}
# ![]({{assets/projects_old_projects_scap_29153526042_1cc9499318.jpg | absolute_url}}
# ![]({{assets/projects_old_projects_scap_29153439162_e0e867c361.jpg | absolute_url}}

# %% [markdown]
# # Goal: Automate Page Creation

# %%
def convert_to_markdown(asset_folder, og_webpage):
    request = requests.get(og_webpage)
    soup = BeautifulSoup(request.text)
    images = soup.find(id="primary").find_all("img")
    
    asset_folder_md = asset_folder.replace("../", "")
    for image in images:
        src = image["src"]
        filename = src.split("/")[-1]
        print('![]({{' +asset_folder_md + filename+ ' | absolute_url}}') 

        data = requests.get(src).content 
        
        # Opening a new file named img with extension .jpg 
        # This file would store the data of the image file 
        f = open(asset_folder + filename,'wb') 
        
        # Storing the image data inside the data variable to the file 
        f.write(data) 
        f.close()
#download_images("../../assets/projects/_old_projects/aye-aye", "https://e4e.ucsd.edu/aye-aye-sleep-monitoring")
# Out:
# ![]({{assets/projects/_old_projects/aye-ayeaye-aye-baby.jpg | absolute_url}}
# ![]({{assets/projects/_old_projects/aye-aye2023.01.09.on-box-render-1074x604.png | absolute_url}}

# %%
import requests
from bs4 import BeautifulSoup
import os
request = requests.get("https://e4e.ucsd.edu/stabilized-aerial-camera-platform")
soup = BeautifulSoup(request.text)
soup = soup.find(id="primary")
soup.find(tag="img")

# %%
from bs4 import Tag
import re

# %%
file = str(soup).split("\n")
file
# Out:
# ['<div class="full-width content-area" id="primary">',
#  '<main class="site-main" id="main" role="main">',
#  '<!-- Main project title -->',
#  '<article class="post-30 page type-page status-publish hentry" id="post-30">',
#  '<header class="entry-header">',
#  '<h1 class="entry-title">Stabilized Aerial Camera Platform</h1>',
#  '<!-- Added subnavigation bar -->',
#  '<nav class="page-navigation" id="page-navigation" role="navigation">',
#  '<!--<h1 class="menu-toggle">Menu</h1>-->',
#  '<div class="screen-reader-text skip-link">',
#  '<a href="#content" title="Skip to content">Skip to content</a>',
#  '</div>',
#  '<div class="menu-stabilized-aerial-camera-platform-container"><ul class="menu" id="menu-stabilized-aerial-camera-platform"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3388" id="menu-item-3388"><a href="https://e4e.ucsd.edu/stabilized-aerial-camera-platform/project-updates">Project Updates</a></li>',
#  '<li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3311" id="menu-item-3311"><a href="https://e4e.ucsd.edu/stabilized-aerial-camera-platform/media">Media</a></li>',
#  '<li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-30 current_page_item menu-item-1475" id="menu-item-1475"><a aria-current="page" href="https://e4e.ucsd.edu/stabilized-aerial-camera-platform">Stabilized Aerial Camera Platform</a></li>',
#  '</ul></div>',
#  '</nav><!-- #page-navigation -->',
#  '</header><!-- .entry-header -->',
#  '<!-- Added ability for only posts from a single category to be displayed on a page titled "Project Updates" -->',
#  '<div class="single-entry-content entry-content">',
#  '<p>\xa0<br/>',
#  'The Aerial Camera Platform is a stabilized camera gimbal levitated via balloon, which provides high quality aerial imagery of the surrounding environment and a high point of view for monitoring applications. Applications include performing real-time wildlife surveys, creating high resolution aerial panoramics, and creating 3D reconstructions of objects or areas.</p>',
#  '<p><a href="https://e4e.ucsd.edu/aerial-camera-platform/attachment/img_1605#main" rel="attachment wp-att-185"><img alt="" class="size-large wp-image-185 aligncenter" decoding="async" fetchpriority="high" height="499" sizes="(max-width: 670px) 100vw, 670px" src="https://e4e.ucsd.edu/wordpress/wp-content/uploads/IMG_1605-1024x764.jpg" srcset="https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-1024x764.jpg 1024w, https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-350x261.jpg 350w, https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-1074x802.jpg 1074w, https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-1536x1147.jpg 1536w, https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-300x224.jpg 300w" title="balloon_geisel" width="670"/></a></p>',
#  '<p class="caption">Aerial Camera Platform deployed in Warren Mall at the University of California, San Diego</p>',
#  '<h2><span>Aerial Imagery</span></h2>',
#  '<p>The Aerial Camera Platform was designed to take aerial panoramic photos and orthophotos. Below are two aerial panoramics created by the Aerial Camera Platform.</p>',
#  '<p><iframe height="400" src="https://e4e.ucsd.edu/iipmooviewer/scripps.html" style="display: block; margin: 0 auto;" width="600"></iframe></p>',
#  '<p class="caption">Gigapan photo of the Scripps Institution of Oceanography taken by Aerial Camera Platform</p>',
#  '<p><iframe height="500" src="https://e4e.ucsd.edu/gigapans/7_30_2013_gigapan/upper_pass_immersive.html" style="display: block; margin: 0 auto;" width="600"></iframe></p>',
#  '<p class="caption">Gigapan of Warren Mall at UC San Diego taken by Aerial Camera Platform</p>',
#  '<h2><span>3D Reconstruction</span></h2>',
#  '<p>One application of the Aerial Camera Platform is the creation of 3D reconstructions from aerial photos using a technique called Structure from Motion. This technique uses overlapping photos of an object or scene to create a 3D rendering of that scene.  This is especially useful in applications such as habitat monitoring, where a 3D rendering provides detailed information about a habitat that is lost in 2D photos.</p>',
#  '<p>We have used the Aerial Camera Platform to create 3D models of various structures and environments, such as an art installation from the Stuart Art Collection seen below.</p>',
#  '<div style="margin: 0px auto; text-align: center"><iframe allowfullscreen="" frameborder="0" height="315" loading="lazy" src="https://www.youtube.com/embed/gDJPp5WQOFw" width="560"></iframe></div>',
#  '<p class="caption">Fallen Star at UCSD, part of the Stuart Art Collection, rendered in 3D by the Aerial Camera Platform</p>',
#  '<p>We have also used the platform to create 3D models of archaeological excavations, notably the excavation of the famed racehorse Native Diver in March 2014. The remains of Native Diver, which had lain at Hollywood Park Racetrack in Inglewood, CA for several decades, were excavated by USC Archaeology and moved to the Del Mar Racetrack after the closure of Hollywood Park. We were on-site to create a 3D model and aerial timelapse of the excavation using our aerial camera system.</p>',
#  '<div style="margin: 0px auto; text-align: center"><iframe allowfullscreen="" frameborder="0" height="400" loading="lazy" src="https://www.youtube.com/embed/Tw7VNB5Eo6c" width="500"></iframe>\xa0\xa0\xa0<iframe allowfullscreen="" frameborder="0" height="400" loading="lazy" src="https://www.youtube.com/embed/jdPi06WAWFM" width="500"></iframe></div>',
#  '<p class="caption">Left: 3D Reconstruction of the excavation site of Native Diver; Right: Aerial timelapse of excavation</p>',
#  '<h2><span>Wildlife and Habitat Monitoring</span></h2>',
#  '<p>Another application of the camera platform is to monitor wildlife and their habitats.  The high point of view afforded by the aerial platform makes it an ideal solution for spotting wildlife from the air at great distances.  Additionally, the platform can be used to create orthophotos to monitor the decline or recovery of wildlife habitats.</p>',
#  '<p>In partnership with the San Dieguito River Valley Conservancy, we have used this platform to monitor the recovery of native plants in the San Dieguito Watershed, where invasive plant species were removed. We created an orthophoto of the area so that conservationists can monitor the growth or decline of native plants in the area after the removal of invasives.</p>',
#  '<p><iframe height="500" loading="lazy" src="https://e4e.ucsd.edu/iipmooviewer/deldios2_0" style="display: block; margin: 0 auto;" width="600"></iframe></p>',
#  '<p class="caption">Orthophoto of Del Dios Gorge in the San Dieguito Watershed, after removal of invasive plants</p>',
#  '<p>We have also used the Aerial Camera Platform to monitor marine wildlife, specifically the gray whale population off the coast of Southern California. The aerial perspective afforded by the camera platform makes it easier to see marine wildlife from a distant vantage point, aiding in population counts and surveys.</p>',
#  '<p><a href="https://e4e.ucsd.edu/wp-content/uploads/balloon_graywhale.png"><img alt="balloon_graywhale" class="aligncenter size-medium wp-image-3286" decoding="async" height="300" loading="lazy" sizes="(max-width: 209px) 100vw, 209px" src="https://e4e.ucsd.edu/wp-content/uploads/balloon_graywhale-209x300.png" srcset="https://e4e.ucsd.edu/wp-content/uploads/balloon_graywhale-209x300.png 209w, https://e4e.ucsd.edu/wp-content/uploads/balloon_graywhale.png 709w" width="209"/></a></p>',
#  '<p class="caption">Deploying the Aerial Camera Platform from a boat to monitor gray whales</p>',
#  '</div><!-- .entry-content -->',
#  '</article><!-- #post-## -->',
#  '</main><!-- #main -->',
#  '</div>']

# %%
asset_folder = "../../assets/projects/_old_projects/aye-aye"
asset_folder_md = asset_folder.replace("../", "")
file = str(soup).split("\n")

new_file = ""
for line in file:
   try:
    if len(re.findall(r"<h\d", line)) > 0:
       print(line, re.findall(r">([^<]+)<", line))
       new_line = "#" + (re.findall(r">([^<]+)<", line)[0]) # * int(line[2])
       new_file += new_line
    if line.startswith("<p"):
       print(line)
       new_file += re.findall(r"p>(.+)</p", line)[0]
    if line.startswith("<li"):
       new_file += " - " + re.findall(r"li>(.+)</li", line)[0]
    if "<img" in line:
       images = re.findall(r"src=\"([/\w.?\-:_]+)\"", line)
       print(images)
       for image in images:
        src = image
        filename = src.split("/")[-1]
        new_file += '![]({{' +asset_folder_md + filename+ ' | absolute_url}}\n' 

        data = requests.get(src).content 
        
        # Opening a new file named img with extension .jpg 
        # This file would store the data of the image file 
        f = open(asset_folder + filename,'wb') 
        
        # Storing the image data inside the data variable to the file 
        f.write(data) 
        f.close()
   except Exception as e:
      new_file += "ERROR " + line
       
   new_file += "\n"

new_file = re.sub(r"(\n)+", "\n", new_file)
print("=============================")
print(new_file)
# Out:
# <h1 class="entry-title">Stabilized Aerial Camera Platform</h1> ['Stabilized Aerial Camera Platform']
# <!--<h1 class="menu-toggle">Menu</h1>--> ['Menu']
# <p> <br/>
# <p><a href="https://e4e.ucsd.edu/aerial-camera-platform/attachment/img_1605#main" rel="attachment wp-att-185"><img alt="" class="size-large wp-image-185 aligncenter" decoding="async" fetchpriority="high" height="499" sizes="(max-width: 670px) 100vw, 670px" src="https://e4e.ucsd.edu/wordpress/wp-content/uploads/IMG_1605-1024x764.jpg" srcset="https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-1024x764.jpg 1024w, https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-350x261.jpg 350w, https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-1074x802.jpg 1074w, https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-1536x1147.jpg 1536w, https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-300x224.jpg 300w" title="balloon_geisel" width="670"/></a></p>
# ['https://e4e.ucsd.edu/wordpress/wp-content/uploads/IMG_1605-1024x764.jpg']
# <p class="caption">Aerial Camera Platform deployed in Warren Mall at the University of California, San Diego</p>
# <h2><span>Aerial Imagery</span></h2> ['Aerial Imagery']
# <p>The Aerial Camera Platform was designed to take aerial panoramic photos and orthophotos. Below are two aerial panoramics created by the Aerial Camera Platform.</p>
# <p><iframe height="400" src="https://e4e.ucsd.edu/iipmooviewer/scripps.html" style="display: block; margin: 0 auto;" width="600"></iframe></p>
# <p class="caption">Gigapan photo of the Scripps Institution of Oceanography taken by Aerial Camera Platform</p>
# <p><iframe height="500" src="https://e4e.ucsd.edu/gigapans/7_30_2013_gigapan/upper_pass_immersive.html" style="display: block; margin: 0 auto;" width="600"></iframe></p>
# <p class="caption">Gigapan of Warren Mall at UC San Diego taken by Aerial Camera Platform</p>
# <h2><span>3D Reconstruction</span></h2> ['3D Reconstruction']
# <p>One application of the Aerial Camera Platform is the creation of 3D reconstructions from aerial photos using a technique called Structure from Motion. This technique uses overlapping photos of an object or scene to create a 3D rendering of that scene.  This is especially useful in applications such as habitat monitoring, where a 3D rendering provides detailed information about a habitat that is lost in 2D photos.</p>
# <p>We have used the Aerial Camera Platform to create 3D models of various structures and environments, such as an art installation from the Stuart Art Collection seen below.</p>
# <p class="caption">Fallen Star at UCSD, part of the Stuart Art Collection, rendered in 3D by the Aerial Camera Platform</p>
# <p>We have also used the platform to create 3D models of archaeological excavations, notably the excavation of the famed racehorse Native Diver in March 2014. The remains of Native Diver, which had lain at Hollywood Park Racetrack in Inglewood, CA for several decades, were excavated by USC Archaeology and moved to the Del Mar Racetrack after the closure of Hollywood Park. We were on-site to create a 3D model and aerial timelapse of the excavation using our aerial camera system.</p>
# <p class="caption">Left: 3D Reconstruction of the excavation site of Native Diver; Right: Aerial timelapse of excavation</p>
# <h2><span>Wildlife and Habitat Monitoring</span></h2> ['Wildlife and Habitat Monitoring']
# <p>Another application of the camera platform is to monitor wildlife and their habitats.  The high point of view afforded by the aerial platform makes it an ideal solution for spotting wildlife from the air at great distances.  Additionally, the platform can be used to create orthophotos to monitor the decline or recovery of wildlife habitats.</p>
# <p>In partnership with the San Dieguito River Valley Conservancy, we have used this platform to monitor the recovery of native plants in the San Dieguito Watershed, where invasive plant species were removed. We created an orthophoto of the area so that conservationists can monitor the growth or decline of native plants in the area after the removal of invasives.</p>
# <p><iframe height="500" loading="lazy" src="https://e4e.ucsd.edu/iipmooviewer/deldios2_0" style="display: block; margin: 0 auto;" width="600"></iframe></p>
# <p class="caption">Orthophoto of Del Dios Gorge in the San Dieguito Watershed, after removal of invasive plants</p>
# <p>We have also used the Aerial Camera Platform to monitor marine wildlife, specifically the gray whale population off the coast of Southern California. The aerial perspective afforded by the camera platform makes it easier to see marine wildlife from a distant vantage point, aiding in population counts and surveys.</p>
# <p><a href="https://e4e.ucsd.edu/wp-content/uploads/balloon_graywhale.png"><img alt="balloon_graywhale" class="aligncenter size-medium wp-image-3286" decoding="async" height="300" loading="lazy" sizes="(max-width: 209px) 100vw, 209px" src="https://e4e.ucsd.edu/wp-content/uploads/balloon_graywhale-209x300.png" srcset="https://e4e.ucsd.edu/wp-content/uploads/balloon_graywhale-209x300.png 209w, https://e4e.ucsd.edu/wp-content/uploads/balloon_graywhale.png 709w" width="209"/></a></p>
# ['https://e4e.ucsd.edu/wp-content/uploads/balloon_graywhale-209x300.png']
# <p class="caption">Deploying the Aerial Camera Platform from a boat to monitor gray whales</p>
# =============================
#
# #Stabilized Aerial Camera Platform
# #Menu
# ERROR <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3311" id="menu-item-3311"><a href="https://e4e.ucsd.edu/stabilized-aerial-camera-platform/media">Media</a></li>
# ERROR <li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-30 current_page_item menu-item-1475" id="menu-item-1475"><a aria-current="page" href="https://e4e.ucsd.edu/stabilized-aerial-camera-platform">Stabilized Aerial Camera Platform</a></li>
# ERROR <p> <br/>
# <a href="https://e4e.ucsd.edu/aerial-camera-platform/attachment/img_1605#main" rel="attachment wp-att-185"><img alt="" class="size-large wp-image-185 aligncenter" decoding="async" fetchpriority="high" height="499" sizes="(max-width: 670px) 100vw, 670px" src="https://e4e.ucsd.edu/wordpress/wp-content/uploads/IMG_1605-1024x764.jpg" srcset="https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-1024x764.jpg 1024w, https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-350x261.jpg 350w, https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-1074x802.jpg 1074w, https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-1536x1147.jpg 1536w, https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-300x224.jpg 300w" title="balloon_geisel" width="670"/></a>![]({{assets/projects/_old_projects/aye-ayeIMG_1605-1024x764.jpg | absolute_url}}
# ERROR <p><a href="https://e4e.ucsd.edu/aerial-camera-platform/attachment/img_1605#main" rel="attachment wp-att-185"><img alt="" class="size-large wp-image-185 aligncenter" decoding="async" fetchpriority="high" height="499" sizes="(max-width: 670px) 100vw, 670px" src="https://e4e.ucsd.edu/wordpress/wp-content/uploads/IMG_1605-1024x764.jpg" srcset="https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-1024x764.jpg 1024w, https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-350x261.jpg 350w, https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-1074x802.jpg 1074w, https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-1536x1147.jpg 1536w, https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-300x224.jpg 300w" title="balloon_geisel" width="670"/></a></p>
# ERROR <p class="caption">Aerial Camera Platform deployed in Warren Mall at the University of California, San Diego</p>
# #Aerial Imagery
# The Aerial Camera Platform was designed to take aerial panoramic photos and orthophotos. Below are two aerial panoramics created by the Aerial Camera Platform.
# <iframe height="400" src="https://e4e.ucsd.edu/iipmooviewer/scripps.html" style="display: block; margin: 0 auto;" width="600"></iframe>
# ERROR <p class="caption">Gigapan photo of the Scripps Institution of Oceanography taken by Aerial Camera Platform</p>
# <iframe height="500" src="https://e4e.ucsd.edu/gigapans/7_30_2013_gigapan/upper_pass_immersive.html" style="display: block; margin: 0 auto;" width="600"></iframe>
# ERROR <p class="caption">Gigapan of Warren Mall at UC San Diego taken by Aerial Camera Platform</p>
# #3D Reconstruction
# One application of the Aerial Camera Platform is the creation of 3D reconstructions from aerial photos using a technique called Structure from Motion. This technique uses overlapping photos of an object or scene to create a 3D rendering of that scene.  This is especially useful in applications such as habitat monitoring, where a 3D rendering provides detailed information about a habitat that is lost in 2D photos.
# We have used the Aerial Camera Platform to create 3D models of various structures and environments, such as an art installation from the Stuart Art Collection seen below.
# ERROR <p class="caption">Fallen Star at UCSD, part of the Stuart Art Collection, rendered in 3D by the Aerial Camera Platform</p>
# We have also used the platform to create 3D models of archaeological excavations, notably the excavation of the famed racehorse Native Diver in March 2014. The remains of Native Diver, which had lain at Hollywood Park Racetrack in Inglewood, CA for several decades, were excavated by USC Archaeology and moved to the Del Mar Racetrack after the closure of Hollywood Park. We were on-site to create a 3D model and aerial timelapse of the excavation using our aerial camera system.
# ERROR <p class="caption">Left: 3D Reconstruction of the excavation site of Native Diver; Right: Aerial timelapse of excavation</p>
# #Wildlife and Habitat Monitoring
# Another application of the camera platform is to monitor wildlife and their habitats.  The high point of view afforded by the aerial platform makes it an ideal solution for spotting wildlife from the air at great distances.  Additionally, the platform can be used to create orthophotos to monitor the decline or recovery of wildlife habitats.
# In partnership with the San Dieguito River Valley Conservancy, we have used this platform to monitor the recovery of native plants in the San Dieguito Watershed, where invasive plant species were removed. We created an orthophoto of the area so that conservationists can monitor the growth or decline of native plants in the area after the removal of invasives.
# <iframe height="500" loading="lazy" src="https://e4e.ucsd.edu/iipmooviewer/deldios2_0" style="display: block; margin: 0 auto;" width="600"></iframe>
# ERROR <p class="caption">Orthophoto of Del Dios Gorge in the San Dieguito Watershed, after removal of invasive plants</p>
# We have also used the Aerial Camera Platform to monitor marine wildlife, specifically the gray whale population off the coast of Southern California. The aerial perspective afforded by the camera platform makes it easier to see marine wildlife from a distant vantage point, aiding in population counts and surveys.
# <a href="https://e4e.ucsd.edu/wp-content/uploads/balloon_graywhale.png"><img alt="balloon_graywhale" class="aligncenter size-medium wp-image-3286" decoding="async" height="300" loading="lazy" sizes="(max-width: 209px) 100vw, 209px" src="https://e4e.ucsd.edu/wp-content/uploads/balloon_graywhale-209x300.png" srcset="https://e4e.ucsd.edu/wp-content/uploads/balloon_graywhale-209x300.png 209w, https://e4e.ucsd.edu/wp-content/uploads/balloon_graywhale.png 709w" width="209"/></a>![]({{assets/projects/_old_projects/aye-ayeballoon_graywhale-209x300.png | absolute_url}}
# ERROR <p><a href="https://e4e.ucsd.edu/wp-content/uploads/balloon_graywhale.png"><img alt="balloon_graywhale" class="aligncenter size-medium wp-image-3286" decoding="async" height="300" loading="lazy" sizes="(max-width: 209px) 100vw, 209px" src="https://e4e.ucsd.edu/wp-content/uploads/balloon_graywhale-209x300.png" srcset="https://e4e.ucsd.edu/wp-content/uploads/balloon_graywhale-209x300.png 209w, https://e4e.ucsd.edu/wp-content/uploads/balloon_graywhale.png 709w" width="209"/></a></p>
# ERROR <p class="caption">Deploying the Aerial Camera Platform from a boat to monitor gray whales</p>

# %%
print(new_file)
# Out:
# #Stabilized Aerial Camera Platform
# #Menu
# ERROR <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3311" id="menu-item-3311"><a href="https://e4e.ucsd.edu/stabilized-aerial-camera-platform/media">Media</a></li>
# ERROR <li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-30 current_page_item menu-item-1475" id="menu-item-1475"><a aria-current="page" href="https://e4e.ucsd.edu/stabilized-aerial-camera-platform">Stabilized Aerial Camera Platform</a></li>
# ERROR <p> <br/>
# <a href="https://e4e.ucsd.edu/aerial-camera-platform/attachment/img_1605#main" rel="attachment wp-att-185"><img alt="" class="size-large wp-image-185 aligncenter" decoding="async" fetchpriority="high" height="499" sizes="(max-width: 670px) 100vw, 670px" src="https://e4e.ucsd.edu/wordpress/wp-content/uploads/IMG_1605-1024x764.jpg" srcset="https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-1024x764.jpg 1024w, https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-350x261.jpg 350w, https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-1074x802.jpg 1074w, https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-1536x1147.jpg 1536w, https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-300x224.jpg 300w" title="balloon_geisel" width="670"/></a>![]({{assets/projects/_old_projects/aye-ayeIMG_1605-1024x764.jpg | absolute_url}}
# ERROR <p><a href="https://e4e.ucsd.edu/aerial-camera-platform/attachment/img_1605#main" rel="attachment wp-att-185"><img alt="" class="size-large wp-image-185 aligncenter" decoding="async" fetchpriority="high" height="499" sizes="(max-width: 670px) 100vw, 670px" src="https://e4e.ucsd.edu/wordpress/wp-content/uploads/IMG_1605-1024x764.jpg" srcset="https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-1024x764.jpg 1024w, https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-350x261.jpg 350w, https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-1074x802.jpg 1074w, https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-1536x1147.jpg 1536w, https://e4e.ucsd.edu/wp-content/uploads/IMG_1605-300x224.jpg 300w" title="balloon_geisel" width="670"/></a></p>
# ERROR <p class="caption">Aerial Camera Platform deployed in Warren Mall at the University of California, San Diego</p>
# #Aerial Imagery
# The Aerial Camera Platform was designed to take aerial panoramic photos and orthophotos. Below are two aerial panoramics created by the Aerial Camera Platform.
# <iframe height="400" src="https://e4e.ucsd.edu/iipmooviewer/scripps.html" style="display: block; margin: 0 auto;" width="600"></iframe>
# ERROR <p class="caption">Gigapan photo of the Scripps Institution of Oceanography taken by Aerial Camera Platform</p>
# <iframe height="500" src="https://e4e.ucsd.edu/gigapans/7_30_2013_gigapan/upper_pass_immersive.html" style="display: block; margin: 0 auto;" width="600"></iframe>
# ERROR <p class="caption">Gigapan of Warren Mall at UC San Diego taken by Aerial Camera Platform</p>
# #3D Reconstruction
# One application of the Aerial Camera Platform is the creation of 3D reconstructions from aerial photos using a technique called Structure from Motion. This technique uses overlapping photos of an object or scene to create a 3D rendering of that scene.  This is especially useful in applications such as habitat monitoring, where a 3D rendering provides detailed information about a habitat that is lost in 2D photos.
# We have used the Aerial Camera Platform to create 3D models of various structures and environments, such as an art installation from the Stuart Art Collection seen below.
# ERROR <p class="caption">Fallen Star at UCSD, part of the Stuart Art Collection, rendered in 3D by the Aerial Camera Platform</p>
# We have also used the platform to create 3D models of archaeological excavations, notably the excavation of the famed racehorse Native Diver in March 2014. The remains of Native Diver, which had lain at Hollywood Park Racetrack in Inglewood, CA for several decades, were excavated by USC Archaeology and moved to the Del Mar Racetrack after the closure of Hollywood Park. We were on-site to create a 3D model and aerial timelapse of the excavation using our aerial camera system.
# ERROR <p class="caption">Left: 3D Reconstruction of the excavation site of Native Diver; Right: Aerial timelapse of excavation</p>
# #Wildlife and Habitat Monitoring
# Another application of the camera platform is to monitor wildlife and their habitats.  The high point of view afforded by the aerial platform makes it an ideal solution for spotting wildlife from the air at great distances.  Additionally, the platform can be used to create orthophotos to monitor the decline or recovery of wildlife habitats.
# In partnership with the San Dieguito River Valley Conservancy, we have used this platform to monitor the recovery of native plants in the San Dieguito Watershed, where invasive plant species were removed. We created an orthophoto of the area so that conservationists can monitor the growth or decline of native plants in the area after the removal of invasives.
# <iframe height="500" loading="lazy" src="https://e4e.ucsd.edu/iipmooviewer/deldios2_0" style="display: block; margin: 0 auto;" width="600"></iframe>
# ERROR <p class="caption">Orthophoto of Del Dios Gorge in the San Dieguito Watershed, after removal of invasive plants</p>
# We have also used the Aerial Camera Platform to monitor marine wildlife, specifically the gray whale population off the coast of Southern California. The aerial perspective afforded by the camera platform makes it easier to see marine wildlife from a distant vantage point, aiding in population counts and surveys.
# <a href="https://e4e.ucsd.edu/wp-content/uploads/balloon_graywhale.png"><img alt="balloon_graywhale" class="aligncenter size-medium wp-image-3286" decoding="async" height="300" loading="lazy" sizes="(max-width: 209px) 100vw, 209px" src="https://e4e.ucsd.edu/wp-content/uploads/balloon_graywhale-209x300.png" srcset="https://e4e.ucsd.edu/wp-content/uploads/balloon_graywhale-209x300.png 209w, https://e4e.ucsd.edu/wp-content/uploads/balloon_graywhale.png 709w" width="209"/></a>![]({{assets/projects/_old_projects/aye-ayeballoon_graywhale-209x300.png | absolute_url}}
# ERROR <p><a href="https://e4e.ucsd.edu/wp-content/uploads/balloon_graywhale.png"><img alt="balloon_graywhale" class="aligncenter size-medium wp-image-3286" decoding="async" height="300" loading="lazy" sizes="(max-width: 209px) 100vw, 209px" src="https://e4e.ucsd.edu/wp-content/uploads/balloon_graywhale-209x300.png" srcset="https://e4e.ucsd.edu/wp-content/uploads/balloon_graywhale-209x300.png 209w, https://e4e.ucsd.edu/wp-content/uploads/balloon_graywhale.png 709w" width="209"/></a></p>
# ERROR <p class="caption">Deploying the Aerial Camera Platform from a boat to monitor gray whales</p>
